# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings ('ignore')

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %%
numerical_df = pd.read_csv(r'numerical_df.csv')
cols = []
for i in range(len(numerical_df.columns)):
    cols.append(numerical_df.columns[i].lower().replace(' ', '_'))
numerical_df.columns = cols
numerical_df
# Out:
#       unnamed:_0  customer_lifetime_value  income  monthly_premium_auto  \
# 0              0              2763.519279   56274                    69
# 1              1              6979.535903       0                    94
# 2              2             12887.431650   48767                   108
# 3              3              7645.861827       0                   106
# 4              4              2813.692575   43836                    73
# ...          ...                      ...     ...                   ...
# 9129        9129             23405.987980   71941                    73
# 9130        9130              3096.511217   21604                    79
# 9131        9131              8163.890428       0                    85
# 9132        9132              7524.442436   21941                    96
# 9133        9133              2611.836866       0                    77
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                          32                              5
# 1                          13                             42
# 2                          18                             38
# 3                          18                             65
# 4                          12                             44
# ...                       ...                            ...
# 9129                       18                             89
# 9130                       14                             28
# 9131                        9                             37
# 9132                       34                              3
# 9133                        3                             90
#
#       number_of_open_complaints  number_of_policies  total_claim_amount
# 0                             0                   1          384.811147
# 1                             0                   8         1131.464935
# 2                             0                   2          566.472247
# 3                             0                   7          529.881344
# 4                             0                   1          138.130879
# ...                         ...                 ...                 ...
# 9129                          0                   2          198.234764
# 9130                          0                   1          379.200000
# 9131                          3                   2          790.784983
# 9132                          0                   3          691.200000
# 9133                          0                   1          369.600000
#
# [9134 rows x 9 columns]

# %%
categorical_df = pd.read_csv(r'categorical_df.csv')
cols = []
for i in range(len(categorical_df.columns)):
    cols.append(categorical_df.columns[i].lower().replace(' ', '_'))
categorical_df.columns = cols
categorical_df
# Out:
#       unnamed:_0 customer       state response  coverage education  \
# 0              0  BU79786  Washington       No     Basic  Bachelor
# 1              1  QZ44356     Arizona       No  Extended  Bachelor
# 2              2  AI49188      Nevada       No   Premium  Bachelor
# 3              3  WW63253  California       No     Basic  Bachelor
# 4              4  HB64268  Washington       No     Basic  Bachelor
# ...          ...      ...         ...      ...       ...       ...
# 9129        9129  LA72316  California       No     Basic  Bachelor
# 9130        9130  PK87824  California      Yes  Extended   College
# 9131        9131  TD14365  California       No  Extended  Bachelor
# 9132        9132  UP19263  California       No  Extended   College
# 9133        9133  Y167826  California       No  Extended   College
#
#      effective_to_date employment_status gender location_code marital_status  \
# 0           2011-02-24          Employed      F      Suburban        Married
# 1           2011-01-31        Unemployed      F      Suburban         Single
# 2           2011-02-19          Employed      F      Suburban        Married
# 3           2011-01-20        Unemployed      M      Suburban        Married
# 4           2011-02-03          Employed      M         Rural         Single
# ...                ...               ...    ...           ...            ...
# 9129        2011-02-10          Employed      M         Urban        Married
# 9130        2011-02-12          Employed      F      Suburban       Divorced
# 9131        2011-02-06        Unemployed      M      Suburban         Single
# 9132        2011-02-03          Employed      M      Suburban        Married
# 9133        2011-02-14        Unemployed      M      Suburban         Single
#
#      renew_offer_type sales_channel  vehicle_class vehicle_size policy_type  \
# 0              Offer1         Agent   Two-Door Car      Medsize   Corporate
# 1              Offer3         Agent  Four-Door Car      Medsize    Personal
# 2              Offer1         Agent   Two-Door Car      Medsize    Personal
# 3              Offer1   Call Center            SUV      Medsize   Corporate
# 4              Offer1         Agent  Four-Door Car      Medsize    Personal
# ...               ...           ...            ...          ...         ...
# 9129           Offer2           Web  Four-Door Car      Medsize    Personal
# 9130           Offer1        Branch  Four-Door Car      Medsize   Corporate
# 9131           Offer1        Branch  Four-Door Car      Medsize   Corporate
# 9132           Offer3        Branch  Four-Door Car        Large    Personal
# 9133           Offer4   Call Center   Two-Door Car      Medsize   Corporate
#
#      policy_number
# 0               L3
# 1               L3
# 2               L3
# 3               L2
# 4               L1
# ...            ...
# 9129            L1
# 9130            L3
# 9131            L2
# 9132            L2
# 9133            L3
#
# [9134 rows x 17 columns]

# %%
customer_df = pd.read_csv(r'files_for_lab\we_fn_use_c_marketing_customer_value_analysis.csv')
cols = []
for i in range(len(customer_df.columns)):
    cols.append(customer_df.columns[i].lower().replace(' ', '_'))
customer_df.columns = cols
customer_df
# Out:
#      customer       state  customer_lifetime_value response  coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      education effective_to_date employmentstatus gender  income  ...  \
# 0     Bachelor           2/24/11         Employed      F   56274  ...
# 1     Bachelor           1/31/11       Unemployed      F       0  ...
# 2     Bachelor           2/19/11         Employed      F   48767  ...
# 3     Bachelor           1/20/11       Unemployed      M       0  ...
# 4     Bachelor            2/3/11         Employed      M   43836  ...
# ...        ...               ...              ...    ...     ...  ...
# 9129  Bachelor           2/10/11         Employed      M   71941  ...
# 9130   College           2/12/11         Employed      F   21604  ...
# 9131  Bachelor            2/6/11       Unemployed      M       0  ...
# 9132   College            2/3/11         Employed      M   21941  ...
# 9133   College           2/14/11       Unemployed      M       0  ...
#
#      months_since_policy_inception number_of_open_complaints  \
# 0                                5                         0
# 1                               42                         0
# 2                               38                         0
# 3                               65                         0
# 4                               44                         0
# ...                            ...                       ...
# 9129                            89                         0
# 9130                            28                         0
# 9131                            37                         3
# 9132                             3                         0
# 9133                            90                         0
#
#       number_of_policies     policy_type        policy  renew_offer_type  \
# 0                      1  Corporate Auto  Corporate L3            Offer1
# 1                      8   Personal Auto   Personal L3            Offer3
# 2                      2   Personal Auto   Personal L3            Offer1
# 3                      7  Corporate Auto  Corporate L2            Offer1
# 4                      1   Personal Auto   Personal L1            Offer1
# ...                  ...             ...           ...               ...
# 9129                   2   Personal Auto   Personal L1            Offer2
# 9130                   1  Corporate Auto  Corporate L3            Offer1
# 9131                   2  Corporate Auto  Corporate L2            Offer1
# 9132                   3   Personal Auto   Personal L2            Offer3
# 9133                   1  Corporate Auto  Corporate L3            Offer4
#
#       sales_channel total_claim_amount  vehicle_class vehicle_size
# 0             Agent         384.811147   Two-Door Car      Medsize
# 1             Agent        1131.464935  Four-Door Car      Medsize
# 2             Agent         566.472247   Two-Door Car      Medsize
# 3       Call Center         529.881344            SUV      Medsize
# 4             Agent         138.130879  Four-Door Car      Medsize
# ...             ...                ...            ...          ...
# 9129            Web         198.234764  Four-Door Car      Medsize
# 9130         Branch         379.200000  Four-Door Car      Medsize
# 9131         Branch         790.784983  Four-Door Car      Medsize
# 9132         Branch         691.200000  Four-Door Car        Large
# 9133    Call Center         369.600000   Two-Door Car      Medsize
#
# [9134 rows x 24 columns]

# %%
customer_df = pd.concat([categorical_df, numerical_df], axis = 1).drop(['unnamed:_0'], axis = 1)
customer_df
# Out:
#      customer       state response  coverage education effective_to_date  \
# 0     BU79786  Washington       No     Basic  Bachelor        2011-02-24
# 1     QZ44356     Arizona       No  Extended  Bachelor        2011-01-31
# 2     AI49188      Nevada       No   Premium  Bachelor        2011-02-19
# 3     WW63253  California       No     Basic  Bachelor        2011-01-20
# 4     HB64268  Washington       No     Basic  Bachelor        2011-02-03
# ...       ...         ...      ...       ...       ...               ...
# 9129  LA72316  California       No     Basic  Bachelor        2011-02-10
# 9130  PK87824  California      Yes  Extended   College        2011-02-12
# 9131  TD14365  California       No  Extended  Bachelor        2011-02-06
# 9132  UP19263  California       No  Extended   College        2011-02-03
# 9133  Y167826  California       No  Extended   College        2011-02-14
#
#      employment_status gender location_code marital_status  ... policy_type  \
# 0             Employed      F      Suburban        Married  ...   Corporate
# 1           Unemployed      F      Suburban         Single  ...    Personal
# 2             Employed      F      Suburban        Married  ...    Personal
# 3           Unemployed      M      Suburban        Married  ...   Corporate
# 4             Employed      M         Rural         Single  ...    Personal
# ...                ...    ...           ...            ...  ...         ...
# 9129          Employed      M         Urban        Married  ...    Personal
# 9130          Employed      F      Suburban       Divorced  ...   Corporate
# 9131        Unemployed      M      Suburban         Single  ...   Corporate
# 9132          Employed      M      Suburban        Married  ...    Personal
# 9133        Unemployed      M      Suburban         Single  ...   Corporate
#
#      policy_number customer_lifetime_value income monthly_premium_auto  \
# 0               L3             2763.519279  56274                   69
# 1               L3             6979.535903      0                   94
# 2               L3            12887.431650  48767                  108
# 3               L2             7645.861827      0                  106
# 4               L1             2813.692575  43836                   73
# ...            ...                     ...    ...                  ...
# 9129            L1            23405.987980  71941                   73
# 9130            L3             3096.511217  21604                   79
# 9131            L2             8163.890428      0                   85
# 9132            L2             7524.442436  21941                   96
# 9133            L3             2611.836866      0                   77
#
#      months_since_last_claim  months_since_policy_inception  \
# 0                         32                              5
# 1                         13                             42
# 2                         18                             38
# 3                         18                             65
# 4                         12                             44
# ...                      ...                            ...
# 9129                      18                             89
# 9130                      14                             28
# 9131                       9                             37
# 9132                      34                              3
# 9133                       3                             90
#
#       number_of_open_complaints  number_of_policies  total_claim_amount
# 0                             0                   1          384.811147
# 1                             0                   8         1131.464935
# 2                             0                   2          566.472247
# 3                             0                   7          529.881344
# 4                             0                   1          138.130879
# ...                         ...                 ...                 ...
# 9129                          0                   2          198.234764
# 9130                          0                   1          379.200000
# 9131                          3                   2          790.784983
# 9132                          0                   3          691.200000
# 9133                          0                   1          369.600000
#
# [9134 rows x 24 columns]

# %%
customer_df.shape
# Out:
# (9134, 24)

# %%
customer_df.isna().sum().sum()
# Out:
# 0

# %%
customer_df.duplicated().sum()
# Out:
# 0

# %%
customer_df.dtypes
# Out:
# customer                          object
# state                             object
# response                          object
# coverage                          object
# education                         object
# effective_to_date                 object
# employment_status                 object
# gender                            object
# location_code                     object
# marital_status                    object
# renew_offer_type                  object
# sales_channel                     object
# vehicle_class                     object
# vehicle_size                      object
# policy_type                       object
# policy_number                     object
# customer_lifetime_value          float64
# income                             int64
# monthly_premium_auto               int64
# months_since_last_claim            int64
# months_since_policy_inception      int64
# number_of_open_complaints          int64
# number_of_policies                 int64
# total_claim_amount               float64
# dtype: object

# %%
customer_df['effective_to_date'] = pd.to_datetime(customer_df['effective_to_date'])
customer_df['day'] = customer_df['effective_to_date'].dt.day
customer_df['month'] = customer_df['effective_to_date'].dt.month
customer_df['year'] = customer_df['effective_to_date'].dt.year
customer_df
# Out:
#      customer       state response  coverage education effective_to_date  \
# 0     BU79786  Washington       No     Basic  Bachelor        2011-02-24
# 1     QZ44356     Arizona       No  Extended  Bachelor        2011-01-31
# 2     AI49188      Nevada       No   Premium  Bachelor        2011-02-19
# 3     WW63253  California       No     Basic  Bachelor        2011-01-20
# 4     HB64268  Washington       No     Basic  Bachelor        2011-02-03
# ...       ...         ...      ...       ...       ...               ...
# 9129  LA72316  California       No     Basic  Bachelor        2011-02-10
# 9130  PK87824  California      Yes  Extended   College        2011-02-12
# 9131  TD14365  California       No  Extended  Bachelor        2011-02-06
# 9132  UP19263  California       No  Extended   College        2011-02-03
# 9133  Y167826  California       No  Extended   College        2011-02-14
#
#      employment_status gender location_code marital_status  ... income  \
# 0             Employed      F      Suburban        Married  ...  56274
# 1           Unemployed      F      Suburban         Single  ...      0
# 2             Employed      F      Suburban        Married  ...  48767
# 3           Unemployed      M      Suburban        Married  ...      0
# 4             Employed      M         Rural         Single  ...  43836
# ...                ...    ...           ...            ...  ...    ...
# 9129          Employed      M         Urban        Married  ...  71941
# 9130          Employed      F      Suburban       Divorced  ...  21604
# 9131        Unemployed      M      Suburban         Single  ...      0
# 9132          Employed      M      Suburban        Married  ...  21941
# 9133        Unemployed      M      Suburban         Single  ...      0
#
#      monthly_premium_auto months_since_last_claim  \
# 0                      69                      32
# 1                      94                      13
# 2                     108                      18
# 3                     106                      18
# 4                      73                      12
# ...                   ...                     ...
# 9129                   73                      18
# 9130                   79                      14
# 9131                   85                       9
# 9132                   96                      34
# 9133                   77                       3
#
#      months_since_policy_inception number_of_open_complaints  \
# 0                                5                         0
# 1                               42                         0
# 2                               38                         0
# 3                               65                         0
# 4                               44                         0
# ...                            ...                       ...
# 9129                            89                         0
# 9130                            28                         0
# 9131                            37                         3
# 9132                             3                         0
# 9133                            90                         0
#
#      number_of_policies  total_claim_amount  day  month  year
# 0                     1          384.811147   24      2  2011
# 1                     8         1131.464935   31      1  2011
# 2                     2          566.472247   19      2  2011
# 3                     7          529.881344   20      1  2011
# 4                     1          138.130879    3      2  2011
# ...                 ...                 ...  ...    ...   ...
# 9129                  2          198.234764   10      2  2011
# 9130                  1          379.200000   12      2  2011
# 9131                  2          790.784983    6      2  2011
# 9132                  3          691.200000    3      2  2011
# 9133                  1          369.600000   14      2  2011
#
# [9134 rows x 27 columns]

# %%
customer_df.columns
# Out:
# Index(['customer', 'state', 'response', 'coverage', 'education',
#        'effective_to_date', 'employment_status', 'gender', 'location_code',
#        'marital_status', 'renew_offer_type', 'sales_channel', 'vehicle_class',
#        'vehicle_size', 'policy_type', 'policy_number',
#        'customer_lifetime_value', 'income', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies', 'total_claim_amount',
#        'day', 'month', 'year'],
#       dtype='object')

# %%
customer_df.select_dtypes(include=['number']).columns.tolist()
numerical_df = customer_df[['customer_lifetime_value',
 'income',
 'monthly_premium_auto',
 'months_since_last_claim',
 'months_since_policy_inception',
 'number_of_open_complaints',
 'number_of_policies',
 'total_claim_amount',
 'day',
 'month',
 'year']]
numerical_df
# Out:
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                 2763.519279   56274                    69
# 1                 6979.535903       0                    94
# 2                12887.431650   48767                   108
# 3                 7645.861827       0                   106
# 4                 2813.692575   43836                    73
# ...                       ...     ...                   ...
# 9129             23405.987980   71941                    73
# 9130              3096.511217   21604                    79
# 9131              8163.890428       0                    85
# 9132              7524.442436   21941                    96
# 9133              2611.836866       0                    77
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                          32                              5
# 1                          13                             42
# 2                          18                             38
# 3                          18                             65
# 4                          12                             44
# ...                       ...                            ...
# 9129                       18                             89
# 9130                       14                             28
# 9131                        9                             37
# 9132                       34                              3
# 9133                        3                             90
#
#       number_of_open_complaints  number_of_policies  total_claim_amount  day  \
# 0                             0                   1          384.811147   24
# 1                             0                   8         1131.464935   31
# 2                             0                   2          566.472247   19
# 3                             0                   7          529.881344   20
# 4                             0                   1          138.130879    3
# ...                         ...                 ...                 ...  ...
# 9129                          0                   2          198.234764   10
# 9130                          0                   1          379.200000   12
# 9131                          3                   2          790.784983    6
# 9132                          0                   3          691.200000    3
# 9133                          0                   1          369.600000   14
#
#       month  year
# 0         2  2011
# 1         1  2011
# 2         2  2011
# 3         1  2011
# 4         2  2011
# ...     ...   ...
# 9129      2  2011
# 9130      2  2011
# 9131      2  2011
# 9132      2  2011
# 9133      2  2011
#
# [9134 rows x 11 columns]

# %%
numerical_df.nunique()
# Out:
# customer_lifetime_value          8041
# income                           5694
# monthly_premium_auto              202
# months_since_last_claim            36
# months_since_policy_inception     100
# number_of_open_complaints           6
# number_of_policies                  9
# total_claim_amount               5106
# day                                31
# month                               2
# year                                1
# dtype: int64

# %%
def get_discrete_df(numerical_df, threshold = 100):
    discrete_columns = [col for col in numerical_df.columns if numerical_df[col].nunique() <= threshold]
    discrete_df = numerical_df[discrete_columns]
    return discrete_df
discrete_df = get_discrete_df(numerical_df)
discrete_df
# Out:
#       months_since_last_claim  months_since_policy_inception  \
# 0                          32                              5
# 1                          13                             42
# 2                          18                             38
# 3                          18                             65
# 4                          12                             44
# ...                       ...                            ...
# 9129                       18                             89
# 9130                       14                             28
# 9131                        9                             37
# 9132                       34                              3
# 9133                        3                             90
#
#       number_of_open_complaints  number_of_policies  day  month  year
# 0                             0                   1   24      2  2011
# 1                             0                   8   31      1  2011
# 2                             0                   2   19      2  2011
# 3                             0                   7   20      1  2011
# 4                             0                   1    3      2  2011
# ...                         ...                 ...  ...    ...   ...
# 9129                          0                   2   10      2  2011
# 9130                          0                   1   12      2  2011
# 9131                          3                   2    6      2  2011
# 9132                          0                   3    3      2  2011
# 9133                          0                   1   14      2  2011
#
# [9134 rows x 7 columns]

# %%
def plot_numerical_variables(discrete_df):
        
    for column in discrete_df:
        sns.boxplot(discrete_df[column], color = 'orange')
        plt.title(f'Distribution of {column}')
        plt.xlabel(column)
        plt.ylabel('Count')
        plt.show()

plot_numerical_variables(discrete_df)

# %%
def get_continuous_df(numerical_df, threshold = 100):
    continuous_columns = [col for col in numerical_df.columns if numerical_df[col].nunique() > threshold]
    continuous_df = numerical_df[continuous_columns]
    return continuous_df
continuous_df = get_continuous_df(numerical_df)
continuous_df
# Out:
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                 2763.519279   56274                    69
# 1                 6979.535903       0                    94
# 2                12887.431650   48767                   108
# 3                 7645.861827       0                   106
# 4                 2813.692575   43836                    73
# ...                       ...     ...                   ...
# 9129             23405.987980   71941                    73
# 9130              3096.511217   21604                    79
# 9131              8163.890428       0                    85
# 9132              7524.442436   21941                    96
# 9133              2611.836866       0                    77
#
#       total_claim_amount
# 0             384.811147
# 1            1131.464935
# 2             566.472247
# 3             529.881344
# 4             138.130879
# ...                  ...
# 9129          198.234764
# 9130          379.200000
# 9131          790.784983
# 9132          691.200000
# 9133          369.600000
#
# [9134 rows x 4 columns]

# %%
def plot_numerical_variables(continuous_df):
        
    for column in continuous_df:
        sns.boxplot(continuous_df[column], color = 'orange')
        plt.title(f'Distribution of {column}')
        plt.xlabel(column)
        plt.ylabel('Count')
        plt.show()

plot_numerical_variables(continuous_df)

# %%
for col in continuous_df.columns:
    Q1 = continuous_df[col].quantile(0.25)
    Q3 = continuous_df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    print(f'Column: {col},\nQ1: {Q1},\nQ3: {Q3},\nIQR: {IQR},\nLower Bound: {lower_bound},\nUpper Bound: {upper_bound}')
# Out:
# Column: customer_lifetime_value,
# Q1: 3994.25179425,
# Q3: 8962.16704125,
# IQR: 4967.915247000001,
# Lower Bound: -3457.6210762500014,
# Upper Bound: 16414.039911750002
# Column: income,
# Q1: 0.0,
# Q3: 62320.0,
# IQR: 62320.0,
# Lower Bound: -93480.0,
# Upper Bound: 155800.0
# Column: monthly_premium_auto,
# Q1: 68.0,
# Q3: 109.0,
# IQR: 41.0,
# Lower Bound: 6.5,
# Upper Bound: 170.5
# Column: total_claim_amount,
# Q1: 272.2582445,
# Q3: 547.51483875,
# IQR: 275.25659425,
# Lower Bound: -140.62664687499995,
# Upper Bound: 960.3997301249999

# %%
sns.boxplot(customer_df['total_claim_amount'], showfliers = False)
# Out:
# <Axes: >

# %%
customer_df.columns
# Out:
# Index(['customer', 'state', 'response', 'coverage', 'education',
#        'effective_to_date', 'employment_status', 'gender', 'location_code',
#        'marital_status', 'renew_offer_type', 'sales_channel', 'vehicle_class',
#        'vehicle_size', 'policy_type', 'policy_number',
#        'customer_lifetime_value', 'income', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies', 'total_claim_amount',
#        'day', 'month', 'year'],
#       dtype='object')

# %%
customer_df['total_claim_amount'].describe()
# Out:
# count    9134.000000
# mean      434.088794
# std       290.500092
# min         0.099007
# 25%       272.258244
# 50%       383.945434
# 75%       547.514839
# max      2893.239678
# Name: total_claim_amount, dtype: float64

# %%
Q1 = customer_df['total_claim_amount'].quantile(0.25)
Q3 = customer_df['total_claim_amount'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
print(f'Column: {col},\nQ1: {Q1},\nQ3: {Q3},\nIQR: {IQR},\nLower Bound: {lower_bound},\nUpper Bound: {upper_bound}')
# Out:
# Column: total_claim_amount,
# Q1: 272.2582445,
# Q3: 547.51483875,
# IQR: 275.25659425,
# Lower Bound: -140.62664687499995,
# Upper Bound: 960.3997301249999

# %%
# Create bins for 'total_claim_amount'
bins = [0, 272.2582445, 383.945434, 547.51483875, 960.3997301249999, 2893.239678]
labels = ['Lower Bound','Q1', 'Q3', 'Upper Bound', 'Outliers']

customer_df['claim_amount_bin'] = pd.cut(customer_df['total_claim_amount'], bins = bins, labels = labels)

grouped = customer_df.groupby('claim_amount_bin')

print('Counts in each group:')
print(grouped.size())
print()

group_stats = grouped['total_claim_amount'].agg(['min', 'max', 'std'])
print('Statistics for each group:')
print(group_stats)
# Out:
# Counts in each group:
# claim_amount_bin
# Lower Bound    2284
# Q1             2283
# Q3             2283
# Upper Bound    1831
# Outliers        453
# dtype: int64
#
# Statistics for each group:
#                          min          max         std
# claim_amount_bin
# Lower Bound         0.099007   272.217171   77.469292
# Q1                272.381465   383.890867   26.969370
# Q3                384.000000   547.200000   46.660073
# Upper Bound       547.619785   960.115399  113.811611
# Outliers          962.159318  2893.239678  311.706116

# %%
customer_df.columns
# Out:
# Index(['customer', 'state', 'response', 'coverage', 'education',
#        'effective_to_date', 'employment_status', 'gender', 'location_code',
#        'marital_status', 'renew_offer_type', 'sales_channel', 'vehicle_class',
#        'vehicle_size', 'policy_type', 'policy_number',
#        'customer_lifetime_value', 'income', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies', 'total_claim_amount',
#        'day', 'month', 'year', 'claim_amount_bin'],
#       dtype='object')

# %%
split_point = 960.3997301249999

customers_no_outliers = customer_df[customer_df['total_claim_amount'] <= split_point]
customers_outliers = customer_df[customer_df['total_claim_amount'] > split_point]

# %%
customers_no_outliers
# Out:
#      customer       state response  coverage education effective_to_date  \
# 0     BU79786  Washington       No     Basic  Bachelor        2011-02-24
# 2     AI49188      Nevada       No   Premium  Bachelor        2011-02-19
# 3     WW63253  California       No     Basic  Bachelor        2011-01-20
# 4     HB64268  Washington       No     Basic  Bachelor        2011-02-03
# 5     OC83172      Oregon      Yes     Basic  Bachelor        2011-01-25
# ...       ...         ...      ...       ...       ...               ...
# 9129  LA72316  California       No     Basic  Bachelor        2011-02-10
# 9130  PK87824  California      Yes  Extended   College        2011-02-12
# 9131  TD14365  California       No  Extended  Bachelor        2011-02-06
# 9132  UP19263  California       No  Extended   College        2011-02-03
# 9133  Y167826  California       No  Extended   College        2011-02-14
#
#      employment_status gender location_code marital_status  ...  \
# 0             Employed      F      Suburban        Married  ...
# 2             Employed      F      Suburban        Married  ...
# 3           Unemployed      M      Suburban        Married  ...
# 4             Employed      M         Rural         Single  ...
# 5             Employed      F         Rural        Married  ...
# ...                ...    ...           ...            ...  ...
# 9129          Employed      M         Urban        Married  ...
# 9130          Employed      F      Suburban       Divorced  ...
# 9131        Unemployed      M      Suburban         Single  ...
# 9132          Employed      M      Suburban        Married  ...
# 9133        Unemployed      M      Suburban         Single  ...
#
#      monthly_premium_auto months_since_last_claim  \
# 0                      69                      32
# 2                     108                      18
# 3                     106                      18
# 4                      73                      12
# 5                      69                      14
# ...                   ...                     ...
# 9129                   73                      18
# 9130                   79                      14
# 9131                   85                       9
# 9132                   96                      34
# 9133                   77                       3
#
#      months_since_policy_inception number_of_open_complaints  \
# 0                                5                         0
# 2                               38                         0
# 3                               65                         0
# 4                               44                         0
# 5                               94                         0
# ...                            ...                       ...
# 9129                            89                         0
# 9130                            28                         0
# 9131                            37                         3
# 9132                             3                         0
# 9133                            90                         0
#
#      number_of_policies total_claim_amount  day  month  year  claim_amount_bin
# 0                     1         384.811147   24      2  2011                Q3
# 2                     2         566.472247   19      2  2011       Upper Bound
# 3                     7         529.881344   20      1  2011                Q3
# 4                     1         138.130879    3      2  2011       Lower Bound
# 5                     2         159.383042   25      1  2011       Lower Bound
# ...                 ...                ...  ...    ...   ...               ...
# 9129                  2         198.234764   10      2  2011       Lower Bound
# 9130                  1         379.200000   12      2  2011                Q1
# 9131                  2         790.784983    6      2  2011       Upper Bound
# 9132                  3         691.200000    3      2  2011       Upper Bound
# 9133                  1         369.600000   14      2  2011                Q1
#
# [8681 rows x 28 columns]

# %%
customers_no_outliers.columns
# Out:
# Index(['customer', 'state', 'response', 'coverage', 'education',
#        'effective_to_date', 'employment_status', 'gender', 'location_code',
#        'marital_status', 'renew_offer_type', 'sales_channel', 'vehicle_class',
#        'vehicle_size', 'policy_type', 'policy_number',
#        'customer_lifetime_value', 'income', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies', 'total_claim_amount',
#        'day', 'month', 'year', 'claim_amount_bin'],
#       dtype='object')

# %%
print("\nStatistics for 'total_claim_amount' <= 960:")
print(customers_no_outliers['total_claim_amount'].agg(['min', 'max', 'std']))
# Out:
# Statistics for 'total_claim_amount' <= 960:
# min      0.099007
# max    960.115399
# std    211.184004
# Name: total_claim_amount, dtype: float64

# %%
customers_no_outliers.describe()
# Out:
#                    effective_to_date  customer_lifetime_value        income  \
# count                           8681              8681.000000   8681.000000
# mean   2011-01-29 20:30:59.509273088              7691.288196  38671.169105
# min              2011-01-01 00:00:00              1898.007675      0.000000
# 25%              2011-01-15 00:00:00              3893.305281  12430.000000
# 50%              2011-01-29 00:00:00              5635.746396  35205.000000
# 75%              2011-02-14 00:00:00              8696.710700  63288.000000
# max              2011-02-28 00:00:00             67907.270500  99981.000000
# std                              NaN              6376.126782  30320.745669
#
#        monthly_premium_auto  months_since_last_claim  \
# count           8681.000000              8681.000000
# mean              89.033061                15.034904
# min               61.000000                 0.000000
# 25%               68.000000                 6.000000
# 50%               80.000000                14.000000
# 75%              106.000000                23.000000
# max              296.000000                35.000000
# std               27.095584                10.072207
#
#        months_since_policy_inception  number_of_open_complaints  \
# count                    8681.000000                8681.000000
# mean                       47.966018                   0.385555
# min                         0.000000                   0.000000
# 25%                        24.000000                   0.000000
# 50%                        48.000000                   0.000000
# 75%                        71.000000                   0.000000
# max                        99.000000                   5.000000
# std                        27.855645                   0.912948
#
#        number_of_policies  total_claim_amount          day        month  \
# count         8681.000000         8681.000000  8681.000000  8681.000000
# mean             2.958530          390.034963    15.492224     1.463311
# min              1.000000            0.099007     1.000000     1.000000
# 25%              1.000000          256.438030     8.000000     1.000000
# 50%              2.000000          364.800000    16.000000     1.000000
# 75%              4.000000          523.815839    23.000000     2.000000
# max              9.000000          960.115399    31.000000     2.000000
# std              2.383001          211.184004     8.665731     0.498681
#
#          year
# count  8681.0
# mean   2011.0
# min    2011.0
# 25%    2011.0
# 50%    2011.0
# 75%    2011.0
# max    2011.0
# std       0.0

# %%
customers_outliers
# Out:
#      customer       state response  coverage             education  \
# 1     QZ44356     Arizona       No  Extended              Bachelor
# 73    HB20453      Oregon       No     Basic              Bachelor
# 135   MS41162     Arizona       No     Basic  High School or Below
# 142   LP84436  California       No  Extended  High School or Below
# 181   KC11055      Nevada       No  Extended              Bachelor
# ...       ...         ...      ...       ...                   ...
# 9049  UZ14076  California       No   Premium  High School or Below
# 9103  CZ57208  California       No     Basic              Bachelor
# 9107  UU42868  California      Yes   Premium  High School or Below
# 9109  JR41742  California       No     Basic               College
# 9125  RX91025  California       No   Premium  High School or Below
#
#      effective_to_date employment_status gender location_code marital_status  \
# 1           2011-01-31        Unemployed      F      Suburban         Single
# 73          2011-02-04        Unemployed      M      Suburban         Single
# 135         2011-01-26        Unemployed      M      Suburban         Single
# 142         2011-01-21        Unemployed      F      Suburban         Single
# 181         2011-01-24          Employed      F      Suburban        Married
# ...                ...               ...    ...           ...            ...
# 9049        2011-02-16          Employed      F      Suburban        Married
# 9103        2011-01-01          Employed      F      Suburban         Single
# 9107        2011-01-26        Unemployed      M      Suburban        Married
# 9109        2011-01-25        Unemployed      M      Suburban         Single
# 9125        2011-01-31        Unemployed      M      Suburban         Single
#
#       ... monthly_premium_auto months_since_last_claim  \
# 1     ...                   94                      13
# 73    ...                  104                      30
# 135   ...                  117                       6
# 142   ...                  127                      30
# 181   ...                  217                       4
# ...   ...                  ...                     ...
# 9049  ...                  266                       4
# 9103  ...                  195                      24
# 9107  ...                  153                      25
# 9109  ...                  108                      23
# 9125  ...                  185                      26
#
#      months_since_policy_inception number_of_open_complaints  \
# 1                               42                         0
# 73                               3                         1
# 135                              1                         0
# 142                             11                         0
# 181                             29                         2
# ...                            ...                       ...
# 9049                            18                         1
# 9103                             1                         0
# 9107                             5                         0
# 9109                            52                         0
# 9125                            35                         0
#
#      number_of_policies total_claim_amount  day  month  year  claim_amount_bin
# 1                     8        1131.464935   31      1  2011          Outliers
# 73                    5         982.399613    4      2  2011          Outliers
# 135                   1         975.107098   26      1  2011          Outliers
# 142                   6        1087.995426   21      1  2011          Outliers
# 181                   4        1122.658899   24      1  2011          Outliers
# ...                 ...                ...  ...    ...   ...               ...
# 9049                  2        2452.894264   16      2  2011          Outliers
# 9103                  4        1329.957905    1      1  2011          Outliers
# 9107                  1        1027.000029   26      1  2011          Outliers
# 9109                  1        1254.177129   25      1  2011          Outliers
# 9125                  2        1950.725547   31      1  2011          Outliers
#
# [453 rows x 28 columns]

# %%
print("\nStatistics for 'total_claim_amount' > 960:")
print(customers_outliers['total_claim_amount'].agg(['min', 'max', 'std']))
# Out:
# Statistics for 'total_claim_amount' > 960:
# min     962.159318
# max    2893.239678
# std     311.706116
# Name: total_claim_amount, dtype: float64

# %%
customers_outliers.describe()
# Out:
#                    effective_to_date  customer_lifetime_value        income  \
# count                            453               453.000000    453.000000
# mean   2011-01-29 12:14:18.278145792             14015.570577  18229.779249
# min              2011-01-01 00:00:00              2840.899849      0.000000
# 25%              2011-01-15 00:00:00              7180.283897      0.000000
# 50%              2011-01-29 00:00:00             10179.717040      0.000000
# 75%              2011-02-13 00:00:00             16793.972800  32948.000000
# max              2011-02-28 00:00:00             83325.381190  98623.000000
# std                              NaN             11623.283795  24411.770547
#
#        monthly_premium_auto  months_since_last_claim  \
# count            453.000000               453.000000
# mean             173.441501                16.286976
# min               80.000000                 0.000000
# 25%              122.000000                 7.000000
# 50%              181.000000                16.000000
# 75%              212.000000                25.000000
# max              298.000000                35.000000
# std               55.105966                10.030340
#
#        months_since_policy_inception  number_of_open_complaints  \
# count                     453.000000                 453.000000
# mean                       49.953642                   0.362031
# min                         0.000000                   0.000000
# 25%                        25.000000                   0.000000
# 50%                        48.000000                   0.000000
# 75%                        74.000000                   0.000000
# max                        99.000000                   5.000000
# std                        28.820394                   0.860421
#
#        number_of_policies  total_claim_amount         day       month    year
# count          453.000000          453.000000  453.000000  453.000000   453.0
# mean             3.112583         1278.308020   14.865342    1.472406  2011.0
# min              1.000000          962.159318    1.000000    1.000000  2011.0
# 25%              1.000000         1051.200000    8.000000    1.000000  2011.0
# 50%              2.000000         1197.713861   14.000000    1.000000  2011.0
# 75%              5.000000         1376.910777   22.000000    2.000000  2011.0
# max              9.000000         2893.239678   31.000000    2.000000  2011.0
# std              2.522140          311.706116    8.408380    0.499790     0.0

# %%
customers_outliers.columns
# Out:
# Index(['customer', 'state', 'response', 'coverage', 'education',
#        'effective_to_date', 'employment_status', 'gender', 'location_code',
#        'marital_status', 'renew_offer_type', 'sales_channel', 'vehicle_class',
#        'vehicle_size', 'policy_type', 'policy_number',
#        'customer_lifetime_value', 'income', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies', 'total_claim_amount',
#        'day', 'month', 'year', 'claim_amount_bin'],
#       dtype='object')

# %%
categorical_columns = customer_df.select_dtypes(exclude = ['number']).columns.tolist()
categorical_columns
# Out:
# ['customer',
#  'state',
#  'response',
#  'coverage',
#  'education',
#  'effective_to_date',
#  'employment_status',
#  'gender',
#  'location_code',
#  'marital_status',
#  'renew_offer_type',
#  'sales_channel',
#  'vehicle_class',
#  'vehicle_size',
#  'policy_type',
#  'policy_number',
#  'claim_amount_bin']

# %%
types_of_unique_values = ['state',
 'coverage',
 'employment_status',
 'location_code',
 'marital_status',
 'sales_channel',
 'vehicle_class',
 'vehicle_size',
 'policy_type',
 'policy_number']
for column in types_of_unique_values:
    unique_values = categorical_df[column].unique()
    print(f'Unique values for {column}:')
    print(unique_values)
    print()
# Out:
# Unique values for state:
# ['Washington' 'Arizona' 'Nevada' 'California' 'Oregon']
#
# Unique values for coverage:
# ['Basic' 'Extended' 'Premium']
#
# Unique values for employment_status:
# ['Employed' 'Unemployed' 'Medical Leave' 'Disabled' 'Retired']
#
# Unique values for location_code:
# ['Suburban' 'Rural' 'Urban']
#
# Unique values for marital_status:
# ['Married' 'Single' 'Divorced']
#
# Unique values for sales_channel:
# ['Agent' 'Call Center' 'Web' 'Branch']
#
# Unique values for vehicle_class:
# ['Two-Door Car' 'Four-Door Car' 'SUV' 'Luxury SUV' 'Sports Car'
#  'Luxury Car']
#
# Unique values for vehicle_size:
# ['Medsize' 'Small' 'Large']
#
# Unique values for policy_type:
# ['Corporate' 'Personal' 'Special']
#
# Unique values for policy_number:
# ['L3' 'L2' 'L1']

# %%
customers_no_outliers = pd.get_dummies(customers_no_outliers, columns = ['state', 'marital_status', 'policy_type', 'policy_number', 'sales_channel', 'vehicle_class'])
customers_outliers = pd.get_dummies(customers_outliers, columns = ['state', 'marital_status', 'policy_type', 'policy_number', 'sales_channel', 'vehicle_class'])

# %%
coverage_mapping = {'Basic': 0, 'Extended': 1, 'Premium': 2}
employment_status_mapping = {"Medical Leave" : 0, "Disabled" : 0, "Unemployed" : 0, "Retired" : 1, "Employed": 2}
location_code_mapping = {'Rural': 0, 'Suburban': 1, 'Urban': 2}
vehicle_size_mapping = {'Small': 0, 'Medsize': 1, 'Large': 2}

customers_no_outliers['coverage_ordinal'] = customers_no_outliers['coverage'].map(coverage_mapping)
customers_no_outliers['employment_status_ordinal'] = customers_no_outliers['employment_status'].map(employment_status_mapping)
customers_no_outliers['location_code_ordinal'] = customers_no_outliers['location_code'].map(location_code_mapping)
customers_no_outliers['vehicle_size_ordinal'] = customers_no_outliers['vehicle_size'].map(vehicle_size_mapping)

customers_outliers['coverage_ordinal'] = customers_outliers['coverage'].map(coverage_mapping)
customers_outliers['employment_status_ordinal'] = customers_outliers['employment_status'].map(employment_status_mapping)
customers_outliers['location_code_ordinal'] = customers_outliers['location_code'].map(location_code_mapping)
customers_outliers['vehicle_size_ordinal'] = customers_outliers['vehicle_size'].map(vehicle_size_mapping)

# %%
customers_no_outliers
# Out:
#      customer response  coverage education effective_to_date  \
# 0     BU79786       No     Basic  Bachelor        2011-02-24
# 2     AI49188       No   Premium  Bachelor        2011-02-19
# 3     WW63253       No     Basic  Bachelor        2011-01-20
# 4     HB64268       No     Basic  Bachelor        2011-02-03
# 5     OC83172      Yes     Basic  Bachelor        2011-01-25
# ...       ...      ...       ...       ...               ...
# 9129  LA72316       No     Basic  Bachelor        2011-02-10
# 9130  PK87824      Yes  Extended   College        2011-02-12
# 9131  TD14365       No  Extended  Bachelor        2011-02-06
# 9132  UP19263       No  Extended   College        2011-02-03
# 9133  Y167826       No  Extended   College        2011-02-14
#
#      employment_status gender location_code renew_offer_type vehicle_size  \
# 0             Employed      F      Suburban           Offer1      Medsize
# 2             Employed      F      Suburban           Offer1      Medsize
# 3           Unemployed      M      Suburban           Offer1      Medsize
# 4             Employed      M         Rural           Offer1      Medsize
# 5             Employed      F         Rural           Offer2      Medsize
# ...                ...    ...           ...              ...          ...
# 9129          Employed      M         Urban           Offer2      Medsize
# 9130          Employed      F      Suburban           Offer1      Medsize
# 9131        Unemployed      M      Suburban           Offer1      Medsize
# 9132          Employed      M      Suburban           Offer3        Large
# 9133        Unemployed      M      Suburban           Offer4      Medsize
#
#       ...  vehicle_class_Four-Door Car  vehicle_class_Luxury Car  \
# 0     ...                        False                     False
# 2     ...                        False                     False
# 3     ...                        False                     False
# 4     ...                         True                     False
# 5     ...                        False                     False
# ...   ...                          ...                       ...
# 9129  ...                         True                     False
# 9130  ...                         True                     False
# 9131  ...                         True                     False
# 9132  ...                         True                     False
# 9133  ...                        False                     False
#
#       vehicle_class_Luxury SUV  vehicle_class_SUV  vehicle_class_Sports Car  \
# 0                        False              False                     False
# 2                        False              False                     False
# 3                        False               True                     False
# 4                        False              False                     False
# 5                        False              False                     False
# ...                        ...                ...                       ...
# 9129                     False              False                     False
# 9130                     False              False                     False
# 9131                     False              False                     False
# 9132                     False              False                     False
# 9133                     False              False                     False
#
#       vehicle_class_Two-Door Car  coverage_ordinal  employment_status_ordinal  \
# 0                           True                 0                          2
# 2                           True                 2                          2
# 3                          False                 0                          0
# 4                          False                 0                          2
# 5                           True                 0                          2
# ...                          ...               ...                        ...
# 9129                       False                 0                          2
# 9130                       False                 1                          2
# 9131                       False                 1                          0
# 9132                       False                 1                          2
# 9133                        True                 1                          0
#
#       location_code_ordinal  vehicle_size_ordinal
# 0                         1                     1
# 2                         1                     1
# 3                         1                     1
# 4                         0                     1
# 5                         0                     1
# ...                     ...                   ...
# 9129                      2                     1
# 9130                      1                     1
# 9131                      1                     1
# 9132                      1                     2
# 9133                      1                     1
#
# [8681 rows x 50 columns]

# %%
customers_outliers
# Out:
#      customer response  coverage             education effective_to_date  \
# 1     QZ44356       No  Extended              Bachelor        2011-01-31
# 73    HB20453       No     Basic              Bachelor        2011-02-04
# 135   MS41162       No     Basic  High School or Below        2011-01-26
# 142   LP84436       No  Extended  High School or Below        2011-01-21
# 181   KC11055       No  Extended              Bachelor        2011-01-24
# ...       ...      ...       ...                   ...               ...
# 9049  UZ14076       No   Premium  High School or Below        2011-02-16
# 9103  CZ57208       No     Basic              Bachelor        2011-01-01
# 9107  UU42868      Yes   Premium  High School or Below        2011-01-26
# 9109  JR41742       No     Basic               College        2011-01-25
# 9125  RX91025       No   Premium  High School or Below        2011-01-31
#
#      employment_status gender location_code renew_offer_type vehicle_size  \
# 1           Unemployed      F      Suburban           Offer3      Medsize
# 73          Unemployed      M      Suburban           Offer1      Medsize
# 135         Unemployed      M      Suburban           Offer1      Medsize
# 142         Unemployed      F      Suburban           Offer3      Medsize
# 181           Employed      F      Suburban           Offer3      Medsize
# ...                ...    ...           ...              ...          ...
# 9049          Employed      F      Suburban           Offer3        Large
# 9103          Employed      F      Suburban           Offer1        Large
# 9107        Unemployed      M      Suburban           Offer2      Medsize
# 9109        Unemployed      M      Suburban           Offer1      Medsize
# 9125        Unemployed      M      Suburban           Offer1        Small
#
#       ...  vehicle_class_Four-Door Car  vehicle_class_Luxury Car  \
# 1     ...                         True                     False
# 73    ...                        False                     False
# 135   ...                        False                     False
# 142   ...                        False                     False
# 181   ...                        False                      True
# ...   ...                          ...                       ...
# 9049  ...                        False                     False
# 9103  ...                        False                     False
# 9107  ...                        False                     False
# 9109  ...                        False                     False
# 9125  ...                        False                     False
#
#       vehicle_class_Luxury SUV  vehicle_class_SUV  vehicle_class_Sports Car  \
# 1                        False              False                     False
# 73                       False              False                      True
# 135                      False               True                     False
# 142                      False              False                      True
# 181                      False              False                     False
# ...                        ...                ...                       ...
# 9049                      True              False                     False
# 9103                      True              False                     False
# 9107                     False               True                     False
# 9109                     False               True                     False
# 9125                     False               True                     False
#
#       vehicle_class_Two-Door Car  coverage_ordinal  employment_status_ordinal  \
# 1                          False                 1                          0
# 73                         False                 0                          0
# 135                        False                 0                          0
# 142                        False                 1                          0
# 181                        False                 1                          2
# ...                          ...               ...                        ...
# 9049                       False                 2                          2
# 9103                       False                 0                          2
# 9107                       False                 2                          0
# 9109                       False                 0                          0
# 9125                       False                 2                          0
#
#       location_code_ordinal  vehicle_size_ordinal
# 1                         1                     1
# 73                        1                     1
# 135                       1                     1
# 142                       1                     1
# 181                       1                     1
# ...                     ...                   ...
# 9049                      1                     2
# 9103                      1                     2
# 9107                      1                     1
# 9109                      1                     1
# 9125                      1                     0
#
# [453 rows x 50 columns]

# %% [markdown]
# ### final df

# %%
customers_no_outliers.to_csv('customers_no_outliers.csv')
customers_outliers.to_csv('customers_outliers.csv')
